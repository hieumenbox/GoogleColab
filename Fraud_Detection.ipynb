# %% [markdown]
# <a href="https://colab.research.google.com/github/hieumenbox/GoogleColab/blob/main/Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Kết nối COLAB với GDrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Unzip file data.zip
# %cd /content/gdrive/MyDrive/fraud_data
# !unzip fraud_data.zip
# Out:
# /content/gdrive/MyDrive/fraud_data
# Archive:  fraud_data.zip
#   inflating: creditcard.csv

# %%
# Reading data
import pandas as pd

df = pd.read_csv("/content/gdrive/MyDrive/fraud_data/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Dem so dong du lieu
df.count()
# Out:
# Time      284807
# V1        284807
# V2        284807
# V3        284807
# V4        284807
# V5        284807
# V6        284807
# V7        284807
# V8        284807
# V9        284807
# V10       284807
# V11       284807
# V12       284807
# V13       284807
# V14       284807
# V15       284807
# V16       284807
# V17       284807
# V18       284807
# V19       284807
# V20       284807
# V21       284807
# V22       284807
# V23       284807
# V24       284807
# V25       284807
# V26       284807
# V27       284807
# V28       284807
# Amount    284807
# Class     284807
# dtype: int64

# %%
#So dong du lieu moi class
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# Train model autoencoder

# %%
df_no_time = df.drop(columns=['Time'])
df_no_time.head()
# Out:
#          V1        V2        V3        V4  ...       V27       V28  Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155  ...  0.133558 -0.021053  149.62      0
# 1  1.191857  0.266151  0.166480  0.448154  ... -0.008983  0.014724    2.69      0
# 2 -1.358354 -1.340163  1.773209  0.379780  ... -0.055353 -0.059752  378.66      0
# 3 -0.966272 -0.185226  1.792993 -0.863291  ...  0.062723  0.061458  123.50      0
# 4 -1.158233  0.877737  1.548718  0.403034  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 30 columns]

# %%
from sklearn.preprocessing import StandardScaler

df_no_time['Amount'] = StandardScaler().fit_transform(df_no_time['Amount'].values.reshape(-1,1))

# %%
df_no_time.head()
# Out:
#          V1        V2        V3        V4  ...       V27       V28    Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155  ...  0.133558 -0.021053  0.244964      0
# 1  1.191857  0.266151  0.166480  0.448154  ... -0.008983  0.014724 -0.342475      0
# 2 -1.358354 -1.340163  1.773209  0.379780  ... -0.055353 -0.059752  1.160686      0
# 3 -0.966272 -0.185226  1.792993 -0.863291  ...  0.062723  0.061458  0.140534      0
# 4 -1.158233  0.877737  1.548718  0.403034  ...  0.219422  0.215153 -0.073403      0
#
# [5 rows x 30 columns]

# %%
# Phan chia du lieu train test
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(df_no_time, test_size =0.2, random_state=42)

# Dieu che du lieu train
X_train = X_train[X_train['Class']==0]
X_train = X_train.drop(columns=['Class'])

# Dieu che X_test
y_test = X_test['Class']
X_test = X_test.drop(columns=['Class'])

X_train = X_train.values
X_test = X_test.values

# %%
print(X_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (227451, 29)
# (56962, 29)
# (56962,)

# %%
from keras.layers import Input, Dense
from keras.models import load_model, Model
from keras.callbacks import ModelCheckpoint

# Xây dựng model
input_dimension = X_train.shape[1]
hidden_size = 128

input_layer = Input(shape=(input_dimension,))
# Encoder
encoder = Dense(hidden_size, activation = "relu") (input_layer)
encoder = Dense(hidden_size //2, activation="relu") (encoder)
encoder = Dense(hidden_size //4, activation="relu") (encoder)

# Decoder
decoder = Dense(hidden_size //4, activation="relu") (encoder)
decoder = Dense(hidden_size //2, activation="relu") (decoder)
decoder = Dense(hidden_size, activation = "relu") (decoder)

# Output
output_layer = Dense(input_dimension, activation="relu") (decoder)

auto_encoder_model= Model(inputs = input_layer, outputs = output_layer)
auto_encoder_model.compile (optimizer ="adam", loss="mse", metrics=['accuracy'])
auto_encoder_model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 29)]              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 128)               3840
# _________________________________________________________________
# dense_29 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_30 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_31 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_32 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_33 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_34 (Dense)             (None, 29)                3741
# =================================================================
# Total params: 29,405
# Trainable params: 29,405
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model
n_epochs = 50
n_batch_size = 32

save_best = ModelCheckpoint(filepath = "/content/gdrive/MyDrive/fraud_data/best.h5", 
                            monitor='val_loss', verbose=1, save_best_only=True)

history = auto_encoder_model.fit(X_train, X_train, batch_size=n_batch_size, epochs=n_epochs,verbose=1,
                                 shuffle=True, callbacks=[save_best],
                                 validation_data=(X_test, X_test))
# Out:
# Epoch 1/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7453 - accuracy: 0.7081 - val_loss: 0.6929 - val_accuracy: 0.8259
#
# Epoch 00001: val_loss improved from inf to 0.69291, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# Epoch 2/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6565 - accuracy: 0.8197 - val_loss: 0.6609 - val_accuracy: 0.8118
#
# Epoch 00002: val_loss improved from 0.69291 to 0.66091, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# Epoch 3/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6177 - accuracy: 0.8637 - val_loss: 0.6430 - val_accuracy: 0.9019
#
# Epoch 00003: val_loss improved from 0.66091 to 0.64302, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# Epoch 4/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6091 - accuracy: 0.8848 - val_loss: 0.6418 - val_accuracy: 0.8870
#
# Epoch 00004: val_loss improved from 0.64302 to 0.64176, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# Epoch 5/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.5976 - accuracy: 0.8857 - val_loss: 0.6383 - val_accuracy: 0.9035
#
# Epoch 00005: val_loss improved from 0.64176 to 0.63829, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# Epoch 6/50
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6096 - accuracy: 0.8880 - val_loss: 0.6370 - val_accuracy: 0.9150
#
# Epoch 00006: val_loss improved from 0.63829 to 0.63703, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# Epoch 7/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6096 - accuracy: 0.8939 - val_loss: 0.6592 - val_accuracy: 0.8595
#
# Epoch 00007: val_loss did not improve from 0.63703
# Epoch 8/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6067 - accuracy: 0.8937 - val_loss: 0.6366 - val_accuracy: 0.9210
#
# Epoch 00008: val_loss improved from 0.63703 to 0.63660, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# Epoch 9/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.5979 - accuracy: 0.8985 - val_loss: 0.6414 - val_accuracy: 0.8863
#
# Epoch 00009: val_loss did not improve from 0.63660
# Epoch 10/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6236 - accuracy: 0.8953 - val_loss: 0.6374 - val_accuracy: 0.9179
#
# Epoch 00010: val_loss did not improve from 0.63660
# Epoch 11/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.5993 - accuracy: 0.9025 - val_loss: 0.6351 - val_accuracy: 0.9248
#
# Epoch 00011: val_loss improved from 0.63660 to 0.63506, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# Epoch 12/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6099 - accuracy: 0.9039 - val_loss: 0.6352 - val_accuracy: 0.9236
#
# Epoch 00012: val_loss did not improve from 0.63506
# Epoch 13/50
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.5890 - accuracy: 0.9127 - val_loss: 0.6357 - val_accuracy: 0.9169
#
# Epoch 00013: val_loss did not improve from 0.63506
# Epoch 14/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.5923 - accuracy: 0.9091 - val_loss: 0.6364 - val_accuracy: 0.9122
#
# Epoch 00014: val_loss did not improve from 0.63506
# Epoch 15/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6108 - accuracy: 0.9026 - val_loss: 0.6346 - val_accuracy: 0.9279
#
# Epoch 00015: val_loss improved from 0.63506 to 0.63458, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# Epoch 16/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.5936 - accuracy: 0.9189 - val_loss: 0.6394 - val_accuracy: 0.9237
#
# Epoch 00016: val_loss did not improve from 0.63458
# Epoch 17/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.5978 - accuracy: 0.9189 - val_loss: 0.6388 - val_accuracy: 0.9267
#
# Epoch 00017: val_loss did not improve from 0.63458
# Epoch 18/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6004 - accuracy: 0.9172 - val_loss: 0.6711 - val_accuracy: 0.8766
#
# Epoch 00018: val_loss did not improve from 0.63458
# Epoch 19/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6247 - accuracy: 0.8956 - val_loss: 0.6383 - val_accuracy: 0.9390
#
# Epoch 00019: val_loss did not improve from 0.63458
# Epoch 20/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6002 - accuracy: 0.9217 - val_loss: 0.6391 - val_accuracy: 0.9257
#
# Epoch 00020: val_loss did not improve from 0.63458
# Epoch 21/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6032 - accuracy: 0.9190 - val_loss: 0.6525 - val_accuracy: 0.8958
#
# Epoch 00021: val_loss did not improve from 0.63458
# Epoch 22/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6115 - accuracy: 0.9156 - val_loss: 0.6382 - val_accuracy: 0.9346
#
# Epoch 00022: val_loss did not improve from 0.63458
# Epoch 23/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6060 - accuracy: 0.9171 - val_loss: 0.6395 - val_accuracy: 0.9225
#
# Epoch 00023: val_loss did not improve from 0.63458
# Epoch 24/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6085 - accuracy: 0.9221 - val_loss: 0.6388 - val_accuracy: 0.9264
#
# Epoch 00024: val_loss did not improve from 0.63458
# Epoch 25/50
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6035 - accuracy: 0.9200 - val_loss: 0.6411 - val_accuracy: 0.9047
#
# Epoch 00025: val_loss did not improve from 0.63458
# Epoch 26/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.5985 - accuracy: 0.9223 - val_loss: 0.6383 - val_accuracy: 0.9290
#
# Epoch 00026: val_loss did not improve from 0.63458
# Epoch 27/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6027 - accuracy: 0.9270 - val_loss: 0.6461 - val_accuracy: 0.8801
#
# Epoch 00027: val_loss did not improve from 0.63458
# Epoch 28/50
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6105 - accuracy: 0.9166 - val_loss: 0.6612 - val_accuracy: 0.8456
#
# Epoch 00028: val_loss did not improve from 0.63458
# Epoch 29/50
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.6242 - accuracy: 0.8704 - val_loss: 0.6586 - val_accuracy: 0.8660
#
# Epoch 00029: val_loss did not improve from 0.63458
# Epoch 30/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6191 - accuracy: 0.8739 - val_loss: 0.6572 - val_accuracy: 0.8852
#
# Epoch 00030: val_loss did not improve from 0.63458
# Epoch 31/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6100 - accuracy: 0.8749 - val_loss: 0.6569 - val_accuracy: 0.8858
#
# Epoch 00031: val_loss did not improve from 0.63458
# Epoch 32/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6257 - accuracy: 0.8717 - val_loss: 0.6573 - val_accuracy: 0.8839
#
# Epoch 00032: val_loss did not improve from 0.63458
# Epoch 33/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6183 - accuracy: 0.8717 - val_loss: 0.6576 - val_accuracy: 0.8759
#
# Epoch 00033: val_loss did not improve from 0.63458
# Epoch 34/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6144 - accuracy: 0.8762 - val_loss: 0.6568 - val_accuracy: 0.8863
#
# Epoch 00034: val_loss did not improve from 0.63458
# Epoch 35/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6269 - accuracy: 0.8728 - val_loss: 0.6586 - val_accuracy: 0.8817
#
# Epoch 00035: val_loss did not improve from 0.63458
# Epoch 36/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6281 - accuracy: 0.8720 - val_loss: 0.6571 - val_accuracy: 0.8886
#
# Epoch 00036: val_loss did not improve from 0.63458
# Epoch 37/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6337 - accuracy: 0.8690 - val_loss: 0.6570 - val_accuracy: 0.8775
#
# Epoch 00037: val_loss did not improve from 0.63458
# Epoch 38/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6175 - accuracy: 0.8705 - val_loss: 0.6567 - val_accuracy: 0.8857
#
# Epoch 00038: val_loss did not improve from 0.63458
# Epoch 39/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6268 - accuracy: 0.8691 - val_loss: 0.6569 - val_accuracy: 0.8839
#
# Epoch 00039: val_loss did not improve from 0.63458
# Epoch 40/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6216 - accuracy: 0.8758 - val_loss: 0.6571 - val_accuracy: 0.8861
#
# Epoch 00040: val_loss did not improve from 0.63458
# Epoch 41/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6340 - accuracy: 0.8725 - val_loss: 0.6500 - val_accuracy: 0.9255
#
# Epoch 00041: val_loss did not improve from 0.63458
# Epoch 42/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6135 - accuracy: 0.9174 - val_loss: 0.6496 - val_accuracy: 0.9317
#
# Epoch 00042: val_loss did not improve from 0.63458
# Epoch 43/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6101 - accuracy: 0.9264 - val_loss: 0.6494 - val_accuracy: 0.9408
#
# Epoch 00043: val_loss did not improve from 0.63458
# Epoch 44/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6119 - accuracy: 0.9256 - val_loss: 0.6494 - val_accuracy: 0.9389
#
# Epoch 00044: val_loss did not improve from 0.63458
# Epoch 45/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6101 - accuracy: 0.9263 - val_loss: 0.6498 - val_accuracy: 0.9263
#
# Epoch 00045: val_loss did not improve from 0.63458
# Epoch 46/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6211 - accuracy: 0.9260 - val_loss: 0.6497 - val_accuracy: 0.9325
#
# Epoch 00046: val_loss did not improve from 0.63458
# Epoch 47/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6063 - accuracy: 0.9294 - val_loss: 0.6515 - val_accuracy: 0.9185
#
# Epoch 00047: val_loss did not improve from 0.63458
# Epoch 48/50
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6232 - accuracy: 0.9203 - val_loss: 0.6525 - val_accuracy: 0.8731
#
# Epoch 00048: val_loss did not improve from 0.63458
# Epoch 49/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6226 - accuracy: 0.9208 - val_loss: 0.6499 - val_accuracy: 0.9094
#
# Epoch 00049: val_loss did not improve from 0.63458
# Epoch 50/50
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.6076 - accuracy: 0.9249 - val_loss: 0.6498 - val_accuracy: 0.9232
#
# Epoch 00050: val_loss did not improve from 0.63458

# %%
# In history

import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend()

plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Kiểm tra việc tái tạo trong tập test
import numpy as np

# Dự đoán
predicts = auto_encoder_model.predict(X_test)
mse = np.mean(np.power(X_test - predicts,2), axis=1)
err_df = pd.DataFrame({'error': mse, 'truth': y_test})

# %%
# In ra histogram của error khi tái tạo các điểm Normal trong tập test
normal_error_df = err_df[(err_df['truth']==0) & (err_df['error'] < 10)]

_ = plt.hist(normal_error_df.error.values, bins= 50)

# %%
# In ra histogram của error khi tái tạo các điểm Fraud trong tập test
fraud_error_df = err_df[(err_df['truth']==1)]
_ = plt.hist(fraud_error_df.error.values, bins= 100)

# %%
# Vẽ ra confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

threshold = 1

y_pred = [1 if e > threshold else 0 for e in err_df.error.values]
conf_matrix = confusion_matrix(err_df.truth, y_pred)

# Vẽ
sns.heatmap(conf_matrix, xticklabels=["Normal", "Fraud"], yticklabels=['Normal','Fraud'], annot=True, fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predited Values")
plt.ylabel("Truth")
plt.show
# Out:
# <function matplotlib.pyplot.show>
